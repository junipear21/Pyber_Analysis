# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = os.path.join("Resources", "city_data.csv")
ride_data_to_load = os.path.join("Resources", "ride_data.csv")

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
pyber_data_df['date_parsed'] = pd.to_datetime(pyber_data_df["date"])
pyber

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
rides = pyber_data_df.groupby("type").size()
rides
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# dtype: int64

# %%
# 2. Get the total drivers for each city type
drivers = city_data_df.groupby("type").driver_count.sum()
drivers
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
fares = pyber_data_df.groupby("type").fare.sum()
fares
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
avg_fare = pyber_data_df.groupby("type").fare.mean()
avg_fare
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# Name: fare, dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
avg_fare_driver = fares / drivers
avg_fare_driver
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
pyber_summary_df = pd.concat([rides, drivers, fares, avg_fare, avg_fare_driver], axis = 1)
pyber_summary_df
# Out:
#              0  driver_count      fare       fare          1
# type
# Rural      125            78   4327.93  34.623440  55.486282
# Suburban   625           490  19356.33  30.970128  39.502714
# Urban     1625          2405  39854.38  24.525772  16.571468

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None

# %%
#  8. Format the columns.
pyber_summary_df.columns = {"Total Rides", "Total Drivers", "Total Fares", "Average Fare", "Average Fare per Driver"}
pyber_summary_df
# Out:
#           Average Fare per Driver  Total Rides  Average Fare  Total Drivers  \
# Rural                         125           78       4327.93      34.623440
# Suburban                      625          490      19356.33      30.970128
# Urban                        1625         2405      39854.38      24.525772
#
#           Total Fares
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type         date_parsed      date_p
# 0             5  Urban 2019-01-14 10:14:22  2019-01-14
# 1            72  Urban 2019-03-04 18:24:09  2019-03-04
# 2            57  Urban 2019-02-24 04:29:00  2019-02-24
# 3            34  Urban 2019-02-10 23:22:03  2019-02-10
# 4            46  Urban 2019-03-06 04:28:35  2019-03-06

# %%
pyber_data_df["date_p"] = [x.date() for x in pyber_data_df.date_parsed]
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type         date_parsed      date_p
# 0             5  Urban 2019-01-14 10:14:22  2019-01-14
# 1            72  Urban 2019-03-04 18:24:09  2019-03-04
# 2            57  Urban 2019-02-24 04:29:00  2019-02-24
# 3            34  Urban 2019-02-10 23:22:03  2019-02-10
# 4            46  Urban 2019-03-06 04:28:35  2019-03-06

# %%
pyber_data_df.groupby(["date_p", "type"]).fare.sum().reset_index()
# Out:
#          date_p      type    fare
# 0    2019-01-01     Rural   43.69
# 1    2019-01-01  Suburban  128.52
# 2    2019-01-01     Urban  127.78
# 3    2019-01-02     Rural   52.12
# 4    2019-01-02  Suburban  274.92
# ..          ...       ...     ...
# 329  2019-05-06     Urban  181.20
# 330  2019-05-07     Rural   44.94
# 331  2019-05-07  Suburban  274.09
# 332  2019-05-07     Urban  258.01
# 333  2019-05-08     Urban  170.82
#
# [334 rows x 3 columns]

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
fare_sum_df = pd.DataFrame(pyber_data_df.groupby(["date", "type"]).fare.sum())
fare_sum_df
# Out:
#                                fare
# date                type
# 2019-01-01 00:08:16 Urban     37.91
# 2019-01-01 00:46:46 Suburban  47.74
# 2019-01-01 02:07:24 Suburban  24.07
# 2019-01-01 03:46:50 Urban      7.57
# 2019-01-01 05:23:21 Urban     10.75
# ...                             ...
# 2019-05-08 04:20:00 Urban     21.99
# 2019-05-08 04:39:49 Urban     18.45
# 2019-05-08 07:29:01 Urban     18.55
# 2019-05-08 11:38:35 Urban     19.77
# 2019-05-08 13:10:18 Urban     18.04
#
# [2375 rows x 1 columns]

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
fare_sum_df.reset_index(inplace = True)

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
fare_sum_pivot = fare_sum_df.pivot(index='date', columns='type', values='fare')
fare_sum_pivot
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-05-08 04:20:00    NaN       NaN  21.99
# 2019-05-08 04:39:49    NaN       NaN  18.45
# 2019-05-08 07:29:01    NaN       NaN  18.55
# 2019-05-08 11:38:35    NaN       NaN  19.77
# 2019-05-08 13:10:18    NaN       NaN  18.04
#
# [2375 rows x 3 columns]

# %%
fare_sum_pivot.index = pd.to_datetime(fare_sum_pivot.index)
fare_sum_pivot.head()
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
fare_sum_pivot = fare_sum_pivot.loc['2019-01-01':'2019-04-29', :]
fare_sum_pivot
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-04-29 20:54:19    NaN       NaN  28.41
# 2019-04-29 21:20:41    NaN       NaN  13.59
# 2019-04-29 22:08:22    NaN     25.75    NaN
# 2019-04-29 23:05:04    NaN       NaN  14.59
# 2019-04-29 23:10:18    NaN     29.39    NaN
#
# [2218 rows x 3 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)
type(fare_sum_pivot.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# 7. Check that the datatype for the index is datetime using df.info()
fare_sum_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2218 entries, 2019-01-01 00:08:16 to 2019-04-29 23:10:18
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     116 non-null    float64
#  1   Suburban  579 non-null    float64
#  2   Urban     1523 non-null   float64
# dtypes: float64(3)
# memory usage: 69.3 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
fare_sum_resample = fare_sum_pivot.resample("W").sum()
fare_sum_resample
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93
# 2019-03-17  163.39    906.20  2044.42
# 2019-03-24  189.76   1122.20  2368.37
# 2019-03-31  199.42   1045.06  1942.77
# 2019-04-07  501.24   1010.73  2356.70
# 2019-04-14  269.79    784.82  2390.72
# 2019-04-21  214.14   1149.27  2303.80
# 2019-04-28  191.85   1357.75  2238.29
# 2019-05-05   67.60    167.92   342.63

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

fare_sum_resample.plot(figsize = (20, 6), 
                       xlabel = ("Date"), 
                       ylabel = ("Fare ($USD)"),
                       ylim = (0, 2600),
                       title = ("Total Fare by City Type"))
plt.savefig('~/../analysis/PyBer_fare_summary.png')

plt.show()
